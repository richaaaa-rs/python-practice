# %%
print("Hello Everyone")
# Out:
# Hello Everyone

# %% [markdown]
# ### WE ARE MAKING ROCK PAPER SCISSOR GAME

# %%
import random

values = ["rock","paper","scissor"]


user = input("enter rock,paper,scissor:")
print("Computer's turn:",computer)

if user == computer:
    print("Match tie")

elif user == "rock" and computer == "paper":
         print("computer is winner")

elif user == "paper" and computer == "scissor":
    print("computer win")

elif user == "paper" and computer == "rock":
         print("user is winner")

elif user == "rock" and computer == "scissor":
         print("user is winner")

elif user == "scissor"and computer == "rock":
         print("computer is winner")

elif user == "rock" and computer == "scissor":
         print("user is winner")

elif user == "scissor" and computer == "paper":
    print("User is winner")

elif  user not in values:
    print("Invalid choice! Please enter rock, paper or scissor.")

computer = random.choice(values)    

play_again = input("\nDo you want to play again? (yes/no): ").lower()

if play_again == "no":
    print("Thanks for playing! 👋")
# Out:
# Computer's turn: paper
# Match tie
# Thanks for playing! 👋
